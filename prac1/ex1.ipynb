# %%
import numpy as np
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

data=[1.3,5.3,3.7,7.8,9.8,6.7,5.6,8.3,3.5,3.6,2.5,2.7,3.7,7.2,7.0,3.0,4.5,5.5,6.2,1.1]

print(data)
plt.hist(data, bins=10, range=(0,10), edgecolor='black')
plt.show()
# Out:
# [1.3, 5.3, 3.7, 7.8, 9.8, 6.7, 5.6, 8.3, 3.5, 3.6, 2.5, 2.7, 3.7, 7.2, 7.0, 3.0, 4.5, 5.5, 6.2, 1.1]

# %%
mean = np.mean(data)
mean
# Out:
# 4.949999999999999

# %%
np.median(data)
# Out:
# 4.9

# %%
mode = stats.mode(data)
# Out:
# ModeResult(mode=array([3.7]), count=array([2]))

# %%
np.ptp(data)
# Out:
# 8.700000000000001

# %%
np.var(data)
# Out:
# 5.3935

# %%
np.std(data)
# Out:
# 2.3223910092833204

# %%
stats.sem(data)
# Out:
# 0.5327930377291276
